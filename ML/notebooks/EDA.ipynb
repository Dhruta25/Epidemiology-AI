# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df  = pd.read_csv("/Users/dhrutamacm2/Desktop/Epidemiology/ML/data/raw/Disease_symptom_and_patient_profile_dataset.csv")
df.head()
# Out:
#        Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0    Influenza   Yes    No     Yes                  Yes   19  Female
# 1  Common Cold    No   Yes     Yes                   No   25  Female
# 2       Eczema    No   Yes     Yes                   No   25  Female
# 3       Asthma   Yes   Yes      No                  Yes   25    Male
# 4       Asthma   Yes   Yes      No                  Yes   25    Male
#
#   Blood Pressure Cholesterol Level Outcome Variable
# 0            Low            Normal         Positive
# 1         Normal            Normal         Negative
# 2         Normal            Normal         Negative
# 3         Normal            Normal         Positive
# 4         Normal            Normal         Positive

# %%
df.columns
# Out:
# Index(['Disease', 'Fever', 'Cough', 'Fatigue', 'Difficulty Breathing', 'Age',
#        'Gender', 'Blood Pressure', 'Cholesterol Level'],
#       dtype='object')

# %%
df = df.iloc[:, :-1]

# %%
y = df['Disease']
x = df.drop(columns=['Disease'])

# %%
y.value_counts()
# Out:
# Disease
# Asthma                            23
# Stroke                            16
# Osteoporosis                      14
# Hypertension                      10
# Diabetes                          10
#                                   ..
# Autism Spectrum Disorder (ASD)     1
# Hypoglycemia                       1
# Fibromyalgia                       1
# Eating Disorders (Anorexia,...     1
# Williams Syndrome                  1
# Name: count, Length: 116, dtype: int64

# %%
temp_df = df.copy()

binary_cols = ["Fever", "Cough", "Fatigue", "Difficulty Breathing"]

temp_df[binary_cols] = temp_df[binary_cols].replace({
    "Yes": 1,
    "No": 0
})
# Out:
# /var/folders/5r/svqhb71956990v7rdb94sdmh0000gn/T/ipykernel_74425/3135022931.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   temp_df[binary_cols] = temp_df[binary_cols].replace({

# %%
temp_df["Gender"] = temp_df["Gender"].map({
    "Male": 1,
    "Female": 0
})

# %%
bp_mapping = {
    "Low": 0,
    "Normal": 1,
    "High": 2
}

df["Blood Pressure"] = df["Blood Pressure"].map(bp_mapping)

# %%
chol_mapping = {
    "Low": 0,
    "Normal": 1,
    "High": 2
}

df["Cholesterol Level"] = df["Cholesterol Level"].map(chol_mapping)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
temp_df["Disease"] = le.fit_transform(temp_df["Disease"])
